# %%
import pandas as pd

# %%
df = pd.read_excel(r"C:\Users\JEFF DESENVOLVEDOR\Desktop\bancos de dados\exercicios curso excel\projeto curso excel.xlsx")

df.head()
# Out:
#         nome  idade  peso
# 0  jefferson     43   110
# 1    luciano     42   116
# 2    marcos      38    89
# 3       jose     35    75

# %% [markdown]
# a linha de codigo df.head é uma função que printa apenas as primeiras linhas da tabela.

# %% [markdown]
# Acima importei um arquivo excel com uma tabela e abri dentro do notebook utilizando a linguagem Python
