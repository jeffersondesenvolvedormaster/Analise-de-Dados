# %% [markdown]
# <a href="https://colab.research.google.com/github/jeffersondesenvolvedormaster/detetivedosdados/blob/Principal/curso_aula_1_IFMG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ESSE NOTEBOOK CORRESPONDE AO ESTUDO DO MODULO 1 DO CURSO: PYTHON BASICO IFMG - ESCRITO EM 03/11/2025, PELO ALUNO JEFFERSON LEMOS SANTOS.

# %% [markdown]
# CÓDIGOS DE FIXAÇÃO DE ESTUDO:
#
# *Iniciando curso, primeira função:

# %%
n1 = float(input('Informe nota 1: '))
n2 = float(input('Informe nota 2: '))
m = (n1 + n2) / 2
if m >= 60:
  print('Aprovado')
else:
  print('Reprovado')
# Out:
# Informe nota 1: 50
# Informe nota 2: 40
# Reprovado

# %%
n1 = 10
n2 = 2.5
nome = 'José'
teste = True
print(n1, n2, nome, teste)
# Out:
# 10 2.5 José True

# %% [markdown]
# acima podemos ver exemplos de variaveis com tipos diferentes: int, float, string, boolean, e uma função nativa do python chamada print que mostra na tela os valores atribuidos entre as aspas.

# %%
print('Bem vindo!')
nome = input('Informe seu nome: ')
# Idade convertida para inteiro
idade = int(input('Informe sua idade: '))
print()
 # Escreve uma linha em branco
# Escreve mensagem usando as variáveis
print('Olá,', nome, 'sua idade é', idade)
print('Até mais!')
# Out:
# Bem vindo!
# Informe seu nome: jefferson
# Informe sua idade: 43
#
# Olá, jefferson sua idade é 43
# Até mais!

# %% [markdown]
# acima na variavel idade temos o uso de duas funçoes uma dentro da outra INT que transforma o valor em numero inteiro e imput (abre uma caixa para o usuarios digitar uma informação) a função imput tem como padrão receber um texto entre as aspasimput0("") que sera mostrado na tela para que o usuario saiba o que tem que digitar.
# obs. a função ´print pode receber dentro dos parentes() variaveis ou funçoes que podem ser combinadas com textos e o que mostra na tela é o resultado das interações dentro das aspas.

# %% [markdown]
# obs 2 tambem podemos usar a função print para simplismente pular uma linha na tela usando um print sem argumentos dentro das aspas ex: print().

# %%
print ('jefferson',sep='oi', end='tchau')
# Out:
# jeffersontchau

# %%
print('jefferson', 'santos',sep='xx', end='zz')
# Out:
# jeffersonxxsantoszz

# %% [markdown]
# acima podemos ver que a funão print pode ter seu comportamento alterado usando a função sep(determina um separador) e a função end(determina o que ira ser feito no final da execução).

# %%
ni = 10 // 3
print('10 // 3 =', ni)
ni = 10 % 3
print('10 % 3 =', ni)
nr = 2.34 * 3.58
print('2.34 * 3.58 =', nr)
nr = 2.99 / 4.1
print('2.99 / 4.1 =', nr)
nr = (10.5 - 7.8) * (3.2 + 200.43)
print('(10.5 - 7.8) * (3.2 + 200.43) =', nr)
# Out:
# 10 // 3 = 3
# 10 % 3 = 1
# 2.34 * 3.58 = 8.3772
# 2.99 / 4.1 = 0.7292682926829269
# (10.5 - 7.8) * (3.2 + 200.43) = 549.801

# %% [markdown]
# Acima operadores aritméticos do Python
#
# + Adição
# - Subtração
# * Multiplicação
# / Divisão
# // Divisão inteira
# % Resto de divisão
# ** Potenciação

# %%
print('Informe dois números')
n1 = float(input('Primeiro número: '))
n2 = float(input('Segundo número: '))
r = n1 + n2
print(n1, '+', n2, '=', r)
r = n1 - n2
print(n1, '-', n2, '=', r)
r = n1 * n2
print(n1, '*', n2, '=', r)
r = n1 / n2
print(n1, '/', n2, '=', r)
# Out:
# Informe dois números
# Primeiro número: 5
# Segundo número: 2
# 5.0 + 2.0 = 7.0
# 5.0 - 2.0 = 3.0
# 5.0 * 2.0 = 10.0
# 5.0 / 2.0 = 2.5

# %% [markdown]
# Acima podemos ver operações matematicas onde dois valores são pedidos em tela para o usuario, usando a funão imput e uma frase de solicitação, àpos isso o código executa as operações e mostra o print do resultado agregando uma string que explica a operação.
# obs. podemos ver que a cada operação o valor da variavel 'r' é alterado assim ganha um novo paramentro pórem continua usando os valores de n1 e n2 determinado no imput isso facilita a escrita do código.

# %%
r= 2
type(r)
# Out:
# int

# %% [markdown]
# acima a funão type que mostra o tipo do valor inserido na variavel no caso é um numero que defalt é 'INT' podendo ser alterado usando a função float como abaixo:

# %%
x= 14.1
type(x)
x=1
type(x)
x=3.2
type(x)
# Out:
# float

# %% [markdown]
# Acima podemos ver que o python entende o tipo de numero e altera automaticamente.

# %%
print('Informe os dados')
nome = input('Nome: ')
sobrenome = input('Sobrenome: ')
idade = int(input('Idade: '))
mensagem = nome + ' ' + sobrenome + ', ' + str(idade)
print(mensagem)
# Out:
# Informe os dados
# Nome: jefferson
# Sobrenome: lemos
# Idade: 43
# jefferson lemos, 43

# %% [markdown]
# acima: O operador + pode ser usado também para concatenar variáveis e literais textuais.
# No entanto, não é possível concatenar diretamente um elemento textual e um elemento
# numérico. Nesse caso, é necessário converter o valor numérico para textual antes da
# concatenação.

# %%
n1 = int(input('Informe um número: '))
n2 = int(input('Informe outro número: '))
print(n1, '==', n2,  n1 == n2)
print(n1, '!=', n2,  n1 != n2)
print(n1, '<', n2,  n1 < n2)
print(n1, '<=', n2,  n1 <= n2)
print(n1, '>', n2,  n1 > n2)
print(n1, '>=', n2,  n1 >= n2)
# Out:
# Informe um número: 10
# Informe outro número: 9
# 10 == 9 False
# 10 != 9 True
# 10 < 9 False
# 10 <= 9 False
# 10 > 9 True
# 10 >= 9 True

# %%
n1 = int(input('Informe um número: '))
n2 = int(input('Informe outro número: '))
print(n1, '==', n2, ' ' , n1 == n2)
print(n1, '!=', n2,' '  , n1 != n2)
print(n1, '<', n2, ' ' , n1 < n2)
print(n1, '<=', n2,' '  , n1 <= n2)
print(n1, '>', n2, ' ' , n1 > n2)
print(n1, '>=', n2, ' ' , n1 >= n2)
# Out:
# Informe um número: 9
# Informe outro número: 10
# 9 == 10   False
# 9 != 10   True
# 9 < 10   True
# 9 <= 10   True
# 9 > 10   False
# 9 >= 10   False

# %% [markdown]
# Descobri um truque ✌ se voce segurar crtl + shift + L o editor seleciona todos os itens iguais assim voce pode altera-los ou exclui-los de uma só vez # TOP

# %%
n1 = int(input('Informe um número: '))
n2 = int(input('Informe outro número: '))
p = (n1 > n2)
q = (n1 != n2)
r = n1>1 and n2<2
print(p, q, r)
# Out:
# Informe um número: 2
# Informe outro número: 1
# True True True

# %% [markdown]
# Acima um codigo que visa descobrir se é TRUE ou FALSE e tambem usa os operadores AND e OR para que o AND seja TRUE dois termos ou mais devem ser iguais ao valor comparado caso contrario é FALSE , para OR ser TRUE pelo menos um termo deve ser igual a valor comparado caso contrario é FALSE, tambem podemos usar operadores lógicos para comparar diretamente dois valores assim o resultado vai ser TRUE ou FALSE

# %% [markdown]
# Função Funcionamento
# abs(n) Retorna o valor absoluto de n
# chr(n) Retorna o caractere representado pelo número n
# ord(n) Retorna o código correspondente ao caractere c
# round(n, d) Arredonda n considerando d casas decimais
# type(n) retorna o tipo de o

# %%
n=3
d=1
c='a'
a=-5.444
print(abs(a))
print(chr(n))
print(ord(c))
print ((abs(round(a, d))))
print(type(n))
# Out:
# 5.444
#
# 97
# 5.4
# <class 'int'>

# %% [markdown]
# ABS = MOSTRA O VALOR SEMPRE POSITIVO,
#
# CHR = MOSTRA O CARACTER QUE REPRESENTA AQUELE NUMERO,
#
# ORD = MOSTRA O NUMERO QUE REPRESENTA O CARACTER,
#
# ROUND = ARREDONDA O NUMERO DE ACORDO COM O NUMERO DE CASAS DETERMINADAS,
#
# TYPE = MOSTRA O TIPO DAQUELA VARIAVEL

# %%
z='JOSÉ'
print (z.lower())

x='JEFF'
r= x.lower()
print(r)
# Out:
# josé
# jeff

# %%
z='JEFFERSON'
x= z.replace('JEFFERSON', 'CHATO')
print(x)
# Out:
# CHATO

# %%
z='JEFFERSON'
x= z.find('E')
print(x)
# Out:
# 1

# %% [markdown]
# Nas funçoes acima trabalhamos com uma variavel de origen que recebe algum metodo usando a sintaxe variavel.metodo dessa forma o metodo que vem depois do ponto executa uma mudança na variavel que vem antes do ponto.

# %%
import math
n = float(input('Informe um número: '))
x = n * math.pi
print('x = n * pi = ', x)
print('Teto de x =', math.ceil(x))
print('Piso de x =', math.floor(x))
print('Log de x na base 10 =', math.log(x, 10))
print('Raiz de x =', math.sqrt(x))
# Out:
# Informe um número: 9
# x = n * pi =  28.274333882308138
# Teto de x = 29
# Piso de x = 28
# Log de x na base 10 = 1.4513923821334587
# Raiz de x = 5.317361552716548

# %%
#log de  28.274... é 1.45139...
#isso se a base da exponenciação for 10
#ou seja 10 elevado à 1.45139 = 28.274...

x= 10 ** 1.4513923821334587
print(x)
# Out:
# 28.274333882308134

# %%
a=9
print(math.sqrt(a))
print(math.exp(a))
print(a*math.pi)
#match.exp expoe o parametro a 2,78 constante de Euler
#match.sqrt é a raiz quadrada do parametro
#match.pi é o valor de PI
# Out:
# 3.0
# 8103.083927575384
# 28.274333882308138

# %% [markdown]
# ABAIXO EXERCICIOS DO MODULO 1 DO CURSO
# PYTHON BASICO (IFMG)

# %%
#PERGUNTA A

#minha resposta:
altura=5
base=3
triangulo=altura*base/2
print(triangulo)
print()

#resposta do livro:

print('Informe os dados do triângulo')
base = float(input('Base: '))
altura = float(input('Altura: '))
area = base * altura / 2
print('A área do triângulo é', area)
# Out:
# 7.5
#
# Informe os dados do triângulo
# Base: 3
# Altura: 5
# A área do triângulo é 7.5

# %%
# PERGUNTA B parte 1

#minha resposta

print('Escreva uma quantidade de segundos')
segundos = float(input('quantos segundos: '))
minutos = segundos / 60
horas = minutos /60
print(f'o total de horas é de: {horas}')
# Out:
# Escreva uma quantidade de segundos
# quantos segundos: 3600
# o total de horas é de: 1.0

# %%
# PERGUNTA B parte 2

#minha resposta

print('Escreva uma quantidade de horas')
horas = float(input('quantas horas: '))
minutos = horas * 60
segundos = minutos * 60

print(f'o total de segundos é de: {int(segundos)}')
# Out:
# Escreva uma quantidade de horas
# quantas horas: 1
# o total de segundos é de: 3600

# %%
#Resposta do livro exercicio B parte 2

print('H:M:S para Segundos')
print('Informe os dados')
horas = int(input('Horas: '))
minutos = int(input('Minutos: '))
segundos = int(input('Segundos: '))
total_segundos = horas * 60 * 60 + minutos * 60 + segundos
print('O total de segundos é', total_segundos)
# Out:
# H:M:S para Segundos
# Informe os dados
# Horas: 1
# Minutos: 0
# Segundos: 0
# O total de segundos é 3600

# %%
#Resposta do livro exercicio B parte
print('Segundos para H:M:S')
total_segundos = int(input('Informe número total de segundos: '))
minutos = total_segundos // 60
segundos = total_segundos % 60
horas = minutos // 60
minutos %= 60
print(horas, ':', minutos, ':', segundos)
# Out:
# Segundos para H:M:S
# Informe número total de segundos: 3600
# 1 : 0 : 0

# %%
#Pergunta C minha resposta

print('Informe os dados')
C = input('O valor investido é de: ')
I = input('A taxa é de : ')
T = input('O tempo em meses é de: ')
J= (float(C) * float(I) * float(T))/100
print(f'O juros recebido no periodo é de: R${J}')
# Out:
# Informe os dados
# O valor investido é de: 100
# A taxa é de : 10
# O tempo em meses é de: 1
# O juros recebido no periodo é de: R$10.0

# %%
#Pergunta C resposta do livro

print('Informe os dados para o cálculo dos juros')
capital = float(input('Capital: '))
taxa = float(input('Taxa de juros: '))
tempo = float(input('Tempo: '))
juros = capital * taxa * tempo / 100
print('O valor dos juros é', juros)
# Out:
# Informe os dados para o cálculo dos juros
# Capital: 100
# Taxa de juros: 10
# Tempo: 1
# O valor dos juros é 10.0

# %% [markdown]
# Esse é o fim do **modulo 1** de Python Basico, curso EAD fornecido pela IFMG (instituto Federal de Minas Gerais) THANKS GOD!
#
# 03/11/2025
# Jefferson Lemos Santos
